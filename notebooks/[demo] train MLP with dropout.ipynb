# %%
import torch
import matplotlib.pyplot as plt
plt.rc('font', size=16)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # 1. Data

# %%
import torch.nn as nn
from torchvision import datasets, transforms

# %%
fmnist_train = datasets.FashionMNIST(
    root="../../../data", train=True, transform=transforms.ToTensor(), download=True)
fmnist_test = datasets.FashionMNIST(
    root="../../../data", train=False, transform=transforms.ToTensor(), download=True)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ../../../data/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting ../../../data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ../../../data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ../../../data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting ../../../data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ../../../data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ../../../data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting ../../../data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ../../../data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ../../../data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting ../../../data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ../../../data/FashionMNIST/raw
# /usr/local/lib/python3.8/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
fmnist_train
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: ../../../data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
fmnist_test
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 10000
#     Root location: ../../../data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

fig, axes = plt.subplots(1, 5, figsize=(13, 4))
plt.subplots_adjust(hspace=0.001, wspace=0.001)

for i in range(5):
    image, label = fmnist_train.__getitem__(i)
    axes[i].imshow(image.squeeze().numpy())
    axes[i].set_title(f'{label} : {labels_map[label]}')
    axes[i].axis('off')

# %% [markdown]
# ## 1.2 DataLoader

# %%
from torch.utils.data import DataLoader

# %%
batch_size = 100

train_loader = DataLoader(fmnist_train, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(fmnist_test, batch_size=batch_size, shuffle=True)

# %%
# Iterate through DataLoader
train_images, train_labels = next(iter(train_loader))
print(f"Feature batch shape: {train_images.shape}")
print(f"Labels batch shape: {train_labels.shape}")
# Out:
# Feature batch shape: torch.Size([100, 1, 28, 28])
# Labels batch shape: torch.Size([100])

# %%
print('Number of iterations per epoch', len(train_loader)) # 60000 // batch_size + 1
# Out:
# Number of iterations per epoch 600

# %% [markdown]
# # 2. Model
#
# ### [torch.nn](https://pytorch.org/tutorials/beginner/nn_tutorial.html) modules -- a base class used to develop all neural network models

# %%
import torch.nn as nn

# %%
input_size = 28*28
output_size = 10
hidden1_size = 256
hidden2_size = 256

p1 = 0.2 # dropout p for hidden layer 1
p2 = 0.5 # dropout p for hidden layer 2

## --- Model 1 (d2l §4.6) -------------------------
## ------ MLP (3 layer network) without dropout --- 
## ------------------------------------------------

class MLP(nn.Module):
    def __init__(self, input_size, hidden1_size, hidden2_size, output_size):
        super().__init__()        
        self.lin1 = nn.Linear(input_size, hidden1_size)        
        self.lin2 = nn.Linear(hidden1_size, hidden2_size)
        self.lin3 = nn.Linear(hidden2_size, output_size)
        self.relu = nn.ReLU()
        
    def forward(self, X):            
        H1  = self.relu(self.lin1(X))
        H2  = self.relu(self.lin2(H1))
        out = self.lin3(H2) 
        return out

## --- Model 2 (d2l §4.6) -------------------------
## ------ MLP with dropout ------------------------ 
## ------------------------------------------------

class MLP_dropout(nn.Module):
    def __init__(self, input_size, hidden1_size, hidden2_size, output_size, p1, p2):
        super().__init__()        
        self.lin1 = nn.Linear(input_size, hidden1_size)        
        self.lin2 = nn.Linear(hidden1_size, hidden2_size)
        self.lin3 = nn.Linear(hidden2_size, output_size)
        self.relu = nn.ReLU()
        self.dropout1 = nn.Dropout(p1)
        self.dropout2 = nn.Dropout(p2)
        
    def forward(self, X):            
        H1  = self.relu(self.lin1(X))
        H1  = self.dropout1(H1)
        H2  = self.relu(self.lin2(H1))
        H2  = self.dropout2(H1)
        out = self.lin3(H2) 
        return out

# %%
# model without dropout
model_Xdropout = MLP(input_size, hidden1_size, hidden2_size, output_size)
model_Xdropout.to(device)

# model with dropout
model_dropout = MLP_dropout(input_size, hidden1_size, hidden2_size, output_size, p1, p2)
model_dropout.to(device)
# Out:
# MLP_dropout(
#   (lin1): Linear(in_features=784, out_features=256, bias=True)
#   (lin2): Linear(in_features=256, out_features=256, bias=True)
#   (lin3): Linear(in_features=256, out_features=10, bias=True)
#   (relu): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
# )

# %%
# count model parameters
print('TOTAL  :', sum(param.numel() for param in model_dropout.parameters() if param.requires_grad))
# Out:
# TOTAL  : 269322

# %% [markdown]
# # 3. Loss

# %%
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# Usage : `loss = criterion(Y_pred, Y)`
#
# **Careful!** <br>
# `nn.CrossEntropyLoss` applies: ``nn.LogSoftmax`` and ``nn.NLLLoss`` (negative log likelihood loss). <br>
# So don't apply softmax in the forward loop. <br>
# ``Y`` is class (digit) labels, not one-hot!   <br>
# ``Y_pred`` has raw scores (logits), no Softmax!

# %% [markdown]
# # 4. Optimization

# %%
import torch.optim as optim

# %%
learning_rate = 0.1
optimizer_Xdropout = torch.optim.SGD(model_Xdropout.parameters(), lr=learning_rate)
optimizer_dropout = torch.optim.SGD(model_dropout.parameters(), lr=learning_rate)

# %% [markdown]
# # 5. Training Loop
#
# ### loss.backward() : calculate dloss/dw_i
#
# ### optimizer.step()  : update network parameters (w_i)
#
# ### optimizer.zero_grad()
# Whenever `loss.backward()` is called, it'll write the gradients and accumulate them in the w_i.grad attribute. <br>
# e.g. try to print out `model.linear1.weight.grad` <br>
# So we need to call `optimizer.zero_grad()` to zero gradient again and again for every iteration.

# %%
def train_1_epoch(model, optimizer, train_loss, train_acc):
    
    model.train()             # set model to training mode

    running_loss = 0.
    running_corrects = 0
    for i, (images, labels) in enumerate(train_loader):
        # reshape images (100, 1, 28, 28) -> (100, 784)
        images = images.reshape(-1, 28*28).to(device) 
        labels = labels.to(device)
        
        # forward
        outputs = model(images)
        
        # loss
        loss = criterion(outputs, labels) # predicted outputs v.s. actual labels
        
        # backwards
        optimizer.zero_grad()  # zero gradient
        loss.backward()        # loss.backward would calculate dloss/dw_i  
        optimizer.step()       # update network parameters (w_i)
        
        # compute statistics (avg. loss, accuracy)
        running_loss += loss.item() * labels.size(0)
        _, predictions = torch.max(outputs, 1)
        running_corrects += torch.sum(predictions == labels.data)
        
        if (i+1)%300 == 0: # every 300 steps, print something
            print(f'epoch {epoch+1}/{num_epochs}, step {i+1}/{len(train_loader)}, loss={loss.item():.4f}')
            
    epoch_loss = running_loss / len(fmnist_train)            ; train_loss.append(epoch_loss)
    epoch_acc  = running_corrects / len(fmnist_train) * 100. ; train_acc.append(epoch_acc)
    print(f'>>> End epoch {epoch+1}, train accuracy = {epoch_acc:.2f}%, train avgLoss = {epoch_loss:.4f}')

    
    
def validation(model, valid_loss, valid_acc):
    
    model.eval()              # set model to evaluation mode
    
    running_loss = 0.
    running_corrects = 0
    
    for i, (images, labels) in enumerate(test_loader):
        
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        
        loss = criterion(outputs, labels)
        
        # compute statistics (avg. loss, accuracy)
        running_loss += loss.item() * labels.size(0)
        _, predictions = torch.max(outputs, 1)
        running_corrects += torch.sum(predictions == labels.data)
    
    valid_loss.append(running_loss/len(test_loader.dataset))
    valid_acc.append(running_corrects/len(test_loader.dataset) * 100.)
    print(f'>>>              valid accuracy = {valid_acc[-1]:.2f}%, valid avgLoss = {valid_loss[-1]:.4f}')

# %% [markdown]
# ### Train model without dropout

# %%
train_loss_Xdropout = []
train_acc_Xdropout = []
valid_loss_Xdropout = []
valid_acc_Xdropout = []

num_epochs = 30
for epoch in range(0, num_epochs):
    train_1_epoch(model_Xdropout, optimizer_Xdropout, train_loss_Xdropout, train_acc_Xdropout)
    validation(model_Xdropout, valid_loss_Xdropout, valid_acc_Xdropout)
# Out:
# epoch 1/30, step 300/600, loss=0.7300
# epoch 1/30, step 600/600, loss=0.5090
# >>> End epoch 1, train accuracy = 73.33%, train avgLoss = 0.7521
# >>>              valid accuracy = 80.24%, valid avgLoss = 0.5405
# epoch 2/30, step 300/600, loss=0.5843
# epoch 2/30, step 600/600, loss=0.4591
# >>> End epoch 2, train accuracy = 83.22%, train avgLoss = 0.4664
# >>>              valid accuracy = 83.44%, valid avgLoss = 0.4561
# epoch 3/30, step 300/600, loss=0.5195
# epoch 3/30, step 600/600, loss=0.5259
# >>> End epoch 3, train accuracy = 85.15%, train avgLoss = 0.4112
# >>>              valid accuracy = 85.03%, valid avgLoss = 0.4160
# epoch 4/30, step 300/600, loss=0.3508
# epoch 4/30, step 600/600, loss=0.3518
# >>> End epoch 4, train accuracy = 86.15%, train avgLoss = 0.3788
# >>>              valid accuracy = 85.68%, valid avgLoss = 0.3963
# epoch 5/30, step 300/600, loss=0.4083
# epoch 5/30, step 600/600, loss=0.3059
# >>> End epoch 5, train accuracy = 86.83%, train avgLoss = 0.3554
# >>>              valid accuracy = 85.96%, valid avgLoss = 0.3868
# epoch 6/30, step 300/600, loss=0.3008
# epoch 6/30, step 600/600, loss=0.2239
# >>> End epoch 6, train accuracy = 87.59%, train avgLoss = 0.3386
# >>>              valid accuracy = 86.88%, valid avgLoss = 0.3602
# epoch 7/30, step 300/600, loss=0.2228
# epoch 7/30, step 600/600, loss=0.3616
# >>> End epoch 7, train accuracy = 88.06%, train avgLoss = 0.3231
# >>>              valid accuracy = 86.46%, valid avgLoss = 0.3656
# epoch 8/30, step 300/600, loss=0.2455
# epoch 8/30, step 600/600, loss=0.4507
# >>> End epoch 8, train accuracy = 88.49%, train avgLoss = 0.3110
# >>>              valid accuracy = 85.11%, valid avgLoss = 0.4222
# epoch 9/30, step 300/600, loss=0.2916
# epoch 9/30, step 600/600, loss=0.4424
# >>> End epoch 9, train accuracy = 88.83%, train avgLoss = 0.3020
# >>>              valid accuracy = 87.38%, valid avgLoss = 0.3487
# epoch 10/30, step 300/600, loss=0.3092
# epoch 10/30, step 600/600, loss=0.2654
# >>> End epoch 10, train accuracy = 89.39%, train avgLoss = 0.2891
# >>>              valid accuracy = 87.22%, valid avgLoss = 0.3500
# epoch 11/30, step 300/600, loss=0.2805
# epoch 11/30, step 600/600, loss=0.1797
# >>> End epoch 11, train accuracy = 89.60%, train avgLoss = 0.2803
# >>>              valid accuracy = 87.68%, valid avgLoss = 0.3420
# epoch 12/30, step 300/600, loss=0.1954
# epoch 12/30, step 600/600, loss=0.3342
# >>> End epoch 12, train accuracy = 89.82%, train avgLoss = 0.2734
# >>>              valid accuracy = 87.48%, valid avgLoss = 0.3526
# epoch 13/30, step 300/600, loss=0.2469
# epoch 13/30, step 600/600, loss=0.2184
# >>> End epoch 13, train accuracy = 90.29%, train avgLoss = 0.2641
# >>>              valid accuracy = 88.29%, valid avgLoss = 0.3285
# epoch 14/30, step 300/600, loss=0.2480
# epoch 14/30, step 600/600, loss=0.3056
# >>> End epoch 14, train accuracy = 90.29%, train avgLoss = 0.2600
# >>>              valid accuracy = 88.41%, valid avgLoss = 0.3285
# epoch 15/30, step 300/600, loss=0.1984
# epoch 15/30, step 600/600, loss=0.2631
# >>> End epoch 15, train accuracy = 90.64%, train avgLoss = 0.2512
# >>>              valid accuracy = 88.33%, valid avgLoss = 0.3229
# epoch 16/30, step 300/600, loss=0.4258
# epoch 16/30, step 600/600, loss=0.3186
# >>> End epoch 16, train accuracy = 90.97%, train avgLoss = 0.2439
# >>>              valid accuracy = 87.39%, valid avgLoss = 0.3419
# epoch 17/30, step 300/600, loss=0.1846
# epoch 17/30, step 600/600, loss=0.1705
# >>> End epoch 17, train accuracy = 91.08%, train avgLoss = 0.2386
# >>>              valid accuracy = 87.96%, valid avgLoss = 0.3310
# epoch 18/30, step 300/600, loss=0.2666
# epoch 18/30, step 600/600, loss=0.2526
# >>> End epoch 18, train accuracy = 91.32%, train avgLoss = 0.2329
# >>>              valid accuracy = 87.59%, valid avgLoss = 0.3392
# epoch 19/30, step 300/600, loss=0.3175
# epoch 19/30, step 600/600, loss=0.2792
# >>> End epoch 19, train accuracy = 91.60%, train avgLoss = 0.2274
# >>>              valid accuracy = 89.09%, valid avgLoss = 0.3121
# epoch 20/30, step 300/600, loss=0.1980
# epoch 20/30, step 600/600, loss=0.1632
# >>> End epoch 20, train accuracy = 91.71%, train avgLoss = 0.2225
# >>>              valid accuracy = 87.75%, valid avgLoss = 0.3412
# epoch 21/30, step 300/600, loss=0.2358
# epoch 21/30, step 600/600, loss=0.1271
# >>> End epoch 21, train accuracy = 92.00%, train avgLoss = 0.2148
# >>>              valid accuracy = 88.37%, valid avgLoss = 0.3321
# epoch 22/30, step 300/600, loss=0.1498
# epoch 22/30, step 600/600, loss=0.3163
# >>> End epoch 22, train accuracy = 92.18%, train avgLoss = 0.2111
# >>>              valid accuracy = 88.56%, valid avgLoss = 0.3255
# epoch 23/30, step 300/600, loss=0.1968
# epoch 23/30, step 600/600, loss=0.3242
# >>> End epoch 23, train accuracy = 92.42%, train avgLoss = 0.2053
# >>>              valid accuracy = 87.14%, valid avgLoss = 0.3503
# epoch 24/30, step 300/600, loss=0.1552
# epoch 24/30, step 600/600, loss=0.2542
# >>> End epoch 24, train accuracy = 92.49%, train avgLoss = 0.2026
# >>>              valid accuracy = 87.88%, valid avgLoss = 0.3378
# epoch 25/30, step 300/600, loss=0.2038
# epoch 25/30, step 600/600, loss=0.1164
# >>> End epoch 25, train accuracy = 92.59%, train avgLoss = 0.1984
# >>>              valid accuracy = 89.13%, valid avgLoss = 0.3161
# epoch 26/30, step 300/600, loss=0.2493
# epoch 26/30, step 600/600, loss=0.2517
# >>> End epoch 26, train accuracy = 92.73%, train avgLoss = 0.1934
# >>>              valid accuracy = 88.74%, valid avgLoss = 0.3220
# epoch 27/30, step 300/600, loss=0.2085
# epoch 27/30, step 600/600, loss=0.0964
# >>> End epoch 27, train accuracy = 92.85%, train avgLoss = 0.1890
# >>>              valid accuracy = 88.79%, valid avgLoss = 0.3237
# epoch 28/30, step 300/600, loss=0.3229
# epoch 28/30, step 600/600, loss=0.2544
# >>> End epoch 28, train accuracy = 93.16%, train avgLoss = 0.1837
# >>>              valid accuracy = 88.45%, valid avgLoss = 0.3426
# epoch 29/30, step 300/600, loss=0.1234
# epoch 29/30, step 600/600, loss=0.2805
# >>> End epoch 29, train accuracy = 93.18%, train avgLoss = 0.1815
# >>>              valid accuracy = 88.51%, valid avgLoss = 0.3285
# epoch 30/30, step 300/600, loss=0.2262
# epoch 30/30, step 600/600, loss=0.1474
# >>> End epoch 30, train accuracy = 93.44%, train avgLoss = 0.1752
# >>>              valid accuracy = 88.51%, valid avgLoss = 0.3356

# %% [markdown]
# ### Train model with dropout

# %%
train_loss_dropout = []
train_acc_dropout = []
valid_loss_dropout = []
valid_acc_dropout = []

for epoch in range(0, num_epochs):
    train_1_epoch(model_dropout, optimizer_dropout, train_loss_dropout, train_acc_dropout)
    validation(model_dropout, valid_loss_dropout, valid_acc_dropout)
# Out:
# epoch 1/30, step 300/600, loss=0.6535
# epoch 1/30, step 600/600, loss=0.6639
# >>> End epoch 1, train accuracy = 73.58%, train avgLoss = 0.7632
# >>>              valid accuracy = 80.83%, valid avgLoss = 0.5288
# epoch 2/30, step 300/600, loss=0.5494
# epoch 2/30, step 600/600, loss=0.6056
# >>> End epoch 2, train accuracy = 81.19%, train avgLoss = 0.5321
# >>>              valid accuracy = 83.30%, valid avgLoss = 0.4730
# epoch 3/30, step 300/600, loss=0.3263
# epoch 3/30, step 600/600, loss=0.5688
# >>> End epoch 3, train accuracy = 83.12%, train avgLoss = 0.4779
# >>>              valid accuracy = 84.00%, valid avgLoss = 0.4430
# epoch 4/30, step 300/600, loss=0.4065
# epoch 4/30, step 600/600, loss=0.5765
# >>> End epoch 4, train accuracy = 83.72%, train avgLoss = 0.4509
# >>>              valid accuracy = 84.66%, valid avgLoss = 0.4267
# epoch 5/30, step 300/600, loss=0.3405
# epoch 5/30, step 600/600, loss=0.5730
# >>> End epoch 5, train accuracy = 84.51%, train avgLoss = 0.4345
# >>>              valid accuracy = 85.42%, valid avgLoss = 0.4092
# epoch 6/30, step 300/600, loss=0.3594
# epoch 6/30, step 600/600, loss=0.3482
# >>> End epoch 6, train accuracy = 84.99%, train avgLoss = 0.4196
# >>>              valid accuracy = 85.68%, valid avgLoss = 0.3977
# epoch 7/30, step 300/600, loss=0.3478
# epoch 7/30, step 600/600, loss=0.4727
# >>> End epoch 7, train accuracy = 85.32%, train avgLoss = 0.4085
# >>>              valid accuracy = 85.59%, valid avgLoss = 0.3950
# epoch 8/30, step 300/600, loss=0.3576
# epoch 8/30, step 600/600, loss=0.3851
# >>> End epoch 8, train accuracy = 85.51%, train avgLoss = 0.4008
# >>>              valid accuracy = 85.70%, valid avgLoss = 0.3964
# epoch 9/30, step 300/600, loss=0.3670
# epoch 9/30, step 600/600, loss=0.3642
# >>> End epoch 9, train accuracy = 85.76%, train avgLoss = 0.3928
# >>>              valid accuracy = 86.23%, valid avgLoss = 0.3814
# epoch 10/30, step 300/600, loss=0.3777
# epoch 10/30, step 600/600, loss=0.3346
# >>> End epoch 10, train accuracy = 86.22%, train avgLoss = 0.3849
# >>>              valid accuracy = 86.43%, valid avgLoss = 0.3768
# epoch 11/30, step 300/600, loss=0.3401
# epoch 11/30, step 600/600, loss=0.5488
# >>> End epoch 11, train accuracy = 86.31%, train avgLoss = 0.3788
# >>>              valid accuracy = 86.43%, valid avgLoss = 0.3787
# epoch 12/30, step 300/600, loss=0.4555
# epoch 12/30, step 600/600, loss=0.3833
# >>> End epoch 12, train accuracy = 86.67%, train avgLoss = 0.3728
# >>>              valid accuracy = 86.95%, valid avgLoss = 0.3700
# epoch 13/30, step 300/600, loss=0.2688
# epoch 13/30, step 600/600, loss=0.3469
# >>> End epoch 13, train accuracy = 86.70%, train avgLoss = 0.3668
# >>>              valid accuracy = 86.53%, valid avgLoss = 0.3727
# epoch 14/30, step 300/600, loss=0.3798
# epoch 14/30, step 600/600, loss=0.2552
# >>> End epoch 14, train accuracy = 86.83%, train avgLoss = 0.3628
# >>>              valid accuracy = 87.06%, valid avgLoss = 0.3610
# epoch 15/30, step 300/600, loss=0.2161
# epoch 15/30, step 600/600, loss=0.3077
# >>> End epoch 15, train accuracy = 86.94%, train avgLoss = 0.3587
# >>>              valid accuracy = 86.85%, valid avgLoss = 0.3643
# epoch 16/30, step 300/600, loss=0.3064
# epoch 16/30, step 600/600, loss=0.2022
# >>> End epoch 16, train accuracy = 87.08%, train avgLoss = 0.3540
# >>>              valid accuracy = 87.23%, valid avgLoss = 0.3574
# epoch 17/30, step 300/600, loss=0.2752
# epoch 17/30, step 600/600, loss=0.3241
# >>> End epoch 17, train accuracy = 87.06%, train avgLoss = 0.3530
# >>>              valid accuracy = 87.11%, valid avgLoss = 0.3591
# epoch 18/30, step 300/600, loss=0.2757
# epoch 18/30, step 600/600, loss=0.3240
# >>> End epoch 18, train accuracy = 87.42%, train avgLoss = 0.3466
# >>>              valid accuracy = 87.57%, valid avgLoss = 0.3480
# epoch 19/30, step 300/600, loss=0.2296
# epoch 19/30, step 600/600, loss=0.3149
# >>> End epoch 19, train accuracy = 87.50%, train avgLoss = 0.3432
# >>>              valid accuracy = 87.59%, valid avgLoss = 0.3432
# epoch 20/30, step 300/600, loss=0.3423
# epoch 20/30, step 600/600, loss=0.4020
# >>> End epoch 20, train accuracy = 87.63%, train avgLoss = 0.3386
# >>>              valid accuracy = 87.39%, valid avgLoss = 0.3497
# epoch 21/30, step 300/600, loss=0.4375
# epoch 21/30, step 600/600, loss=0.3198
# >>> End epoch 21, train accuracy = 87.90%, train avgLoss = 0.3370
# >>>              valid accuracy = 87.66%, valid avgLoss = 0.3436
# epoch 22/30, step 300/600, loss=0.3508
# epoch 22/30, step 600/600, loss=0.3484
# >>> End epoch 22, train accuracy = 87.76%, train avgLoss = 0.3327
# >>>              valid accuracy = 87.61%, valid avgLoss = 0.3443
# epoch 23/30, step 300/600, loss=0.6642
# epoch 23/30, step 600/600, loss=0.2303
# >>> End epoch 23, train accuracy = 87.86%, train avgLoss = 0.3312
# >>>              valid accuracy = 87.56%, valid avgLoss = 0.3477
# epoch 24/30, step 300/600, loss=0.4570
# epoch 24/30, step 600/600, loss=0.3930
# >>> End epoch 24, train accuracy = 87.91%, train avgLoss = 0.3300
# >>>              valid accuracy = 87.82%, valid avgLoss = 0.3396
# epoch 25/30, step 300/600, loss=0.3191
# epoch 25/30, step 600/600, loss=0.2950
# >>> End epoch 25, train accuracy = 87.95%, train avgLoss = 0.3283
# >>>              valid accuracy = 88.00%, valid avgLoss = 0.3373
# epoch 26/30, step 300/600, loss=0.2775
# epoch 26/30, step 600/600, loss=0.3817
# >>> End epoch 26, train accuracy = 88.17%, train avgLoss = 0.3223
# >>>              valid accuracy = 88.18%, valid avgLoss = 0.3342
# epoch 27/30, step 300/600, loss=0.1854
# epoch 27/30, step 600/600, loss=0.2775
# >>> End epoch 27, train accuracy = 88.15%, train avgLoss = 0.3212
# >>>              valid accuracy = 88.11%, valid avgLoss = 0.3386
# epoch 28/30, step 300/600, loss=0.2834
# epoch 28/30, step 600/600, loss=0.5613
# >>> End epoch 28, train accuracy = 88.47%, train avgLoss = 0.3195
# >>>              valid accuracy = 87.96%, valid avgLoss = 0.3361
# epoch 29/30, step 300/600, loss=0.3440
# epoch 29/30, step 600/600, loss=0.3627
# >>> End epoch 29, train accuracy = 88.44%, train avgLoss = 0.3162
# >>>              valid accuracy = 87.69%, valid avgLoss = 0.3411
# epoch 30/30, step 300/600, loss=0.3128
# epoch 30/30, step 600/600, loss=0.3551
# >>> End epoch 30, train accuracy = 88.36%, train avgLoss = 0.3157
# >>>              valid accuracy = 87.86%, valid avgLoss = 0.3377

# %% [markdown]
# # Plots

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
plt.rc('font', size=16)

ax[0].plot(range(1,num_epochs+1), train_loss_Xdropout, 'o--', label='No dropout (train)', color='b')
ax[1].plot(range(1,num_epochs+1), train_acc_Xdropout , 'o--', label='No dropout (train)', color='b')
ax[0].plot(range(1,num_epochs+1), valid_loss_Xdropout, 'o--', label='No dropout (valid)', color='dodgerblue')
ax[1].plot(range(1,num_epochs+1), valid_acc_Xdropout , 'o--', label='No dropout (valid)', color='dodgerblue')

ax[0].plot(range(1,num_epochs+1), train_loss_dropout, '^--', label='With dropout (train)', color='firebrick')
ax[1].plot(range(1,num_epochs+1), train_acc_dropout , '^--', label='With dropout (train)', color='firebrick')
ax[0].plot(range(1,num_epochs+1), valid_loss_dropout, '^--', label='With dropout (valid)', color='darkorange')
ax[1].plot(range(1,num_epochs+1), valid_acc_dropout , '^--', label='With dropout (valid)', color='darkorange')


ax[0].set_ylabel('loss')
ax[1].set_ylabel('accuracy')

for i in range(2):
    ax[i].set_xlabel('epoch')
    ax[i].legend(loc='best')

# %% [markdown]
# # ------------ End ------------
